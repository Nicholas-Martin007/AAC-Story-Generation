# %%
import pandas as pd

llama_results = [
    "inference_results__home_dev_Downloads_Llama-3_2-3B-Instruct__1.csv",
    # "inference_results__home_dev_Downloads_Llama-3_2-3B-Instruct__2.csv",
]

mistral_results = [
    "inference_results__home_dev_Downloads_Mistral-7B-Instruct-v0_3__1.csv",
    # "inference_results__home_dev_Downloads_Mistral-7B-Instruct-v0_3__2.csv",
]

flan_results = [
    "inference_results_google_flan-t5-large_1.csv",
    # "inference_results_google_flan-t5-large_2.csv",
]

llama_df = pd.concat([pd.read_csv(f) for f in llama_results], ignore_index=True)
mistral_df = pd.concat([pd.read_csv(f) for f in mistral_results], ignore_index=True)
flan_df = pd.concat([pd.read_csv(f) for f in flan_results], ignore_index=True)


print("Average time_sec Llama:", llama_df["time_sec"].mean())
print("Average time_sec Mistral:", mistral_df["time_sec"].mean())
print("Average time_sec Flan-T5:", flan_df["time_sec"].mean())
# Out:
# Average time_sec Llama: 3.4807233667373656
# Average time_sec Mistral: 11.181626400947572
# Average time_sec Flan-T5: 0.17827940464019773
